# %% [markdown]
# # Can We Predict Tomorrow's Snow?: A Data-Driven Approach
# ## Team Info
# *Name:* Yeojin Kim
# *E-mail:* u1375950@utah.edu
# *UID:* u1375950
#
# *Name:*    Daniel Collins
# *E-mail:*   u1513590@utah.edu
# *UID:* u1513590
#
# *Name:*     Hugo Hoyer
# *E-mail:*   u1505072@utah.edu
# *UID:*  u1505072

# %% [markdown]
# # Collecting and Storing the Data
# After determining the [website](https://weatherstack.com/) we were going to use for the weather data, we needed to store ten years of weather data in a csv file.

# %%
import requests 
import pandas as pd
import json

# %% [markdown]
# ## Part 1: Practicing
#
# Tested what a single API request looked like and used the result to expieriement on so that we didn't waste the limited requests we had available.

# %%
url = "https://api.weatherstack.com/historical?access_key=3b38d4e26797a56261880014825a85a7"

querystring = {"query":"Salt Lake City", "historical_date":"2015-01-21", "hourly":1}

response = requests.get(url, params=querystring)

print(response.json())
# Out:
# {'request': {'type': 'City', 'query': 'Salt Lake City, United States of America', 'language': 'en', 'unit': 'm'}, 'location': {'name': 'Salt Lake City', 'country': 'United States of America', 'region': 'Utah', 'lat': '40.761', 'lon': '-111.890', 'timezone_id': 'America/Denver', 'localtime': '2025-03-28 20:33', 'localtime_epoch': 1743193980, 'utc_offset': '-6.0'}, 'current': {'observation_time': '02:33 AM', 'temperature': 11, 'weather_code': 116, 'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'], 'weather_descriptions': ['Partly cloudy'], 'wind_speed': 4, 'wind_degree': 324, 'wind_dir': 'NW', 'pressure': 1009, 'precip': 0, 'humidity': 41, 'cloudcover': 75, 'feelslike': 11, 'uv_index': 0, 'visibility': 14, 'is_day': 'no'}, 'historical': {'2015-01-21': {'date': '2015-01-21', 'date_epoch': 1421798400, 'astro': {'sunrise': '07:47 AM', 'sunset': '05:32 PM', 'moonrise': '08:18 AM', 'moonset': '07:25 PM', 'moon_phase': 'Waxing Crescent', 'moon_illumination': 3}, 'mintemp': -6, 'maxtemp': 1, 'avgtemp': -3, 'totalsnow': 0, 'sunhour': 10, 'uv_index': 2, 'hourly': [{'time': '0', 'temperature': -3, 'wind_speed': 5, 'wind_degree': 354, 'wind_dir': 'N', 'weather_code': 113, 'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'], 'weather_descriptions': ['Clear'], 'precip': 0, 'humidity': 77, 'visibility': 10, 'pressure': 1028, 'cloudcover': 10, 'heatindex': -3, 'dewpoint': -7, 'windchill': -5, 'windgust': 10, 'feelslike': -5, 'chanceofrain': 0, 'chanceofremdry': 0, 'chanceofwindy': 0, 'chanceofovercast': 0, 'chanceofsunshine': 0, 'chanceoffrost': 0, 'chanceofhightemp': 0, 'chanceoffog': 0, 'chanceofsnow': 0, 'chanceofthunder': 0, 'uv_index': 1}, {'time': '300', 'temperature': -4, 'wind_speed': 5, 'wind_degree': 9, 'wind_dir': 'N', 'weather_code': 113, 'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'], 'weather_descriptions': ['Clear'], 'precip': 0, 'humidity': 78, 'visibility': 10, 'pressure': 1029, 'cloudcover': 6, 'heatindex': -4, 'dewpoint': -7, 'windchill': -6, 'windgust': 9, 'feelslike': -6, 'chanceofrain': 0, 'chanceofremdry': 0, 'chanceofwindy': 0, 'chanceofovercast': 0, 'chanceofsunshine': 0, 'chanceoffrost': 0, 'chanceofhightemp': 0, 'chanceoffog': 0, 'chanceofsnow': 0, 'chanceofthunder': 0, 'uv_index': 1}, {'time': '600', 'temperature': -6, 'wind_speed': 3, 'wind_degree': 285, 'wind_dir': 'WNW', 'weather_code': 113, 'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'], 'weather_descriptions': ['Sunny'], 'precip': 0, 'humidity': 80, 'visibility': 10, 'pressure': 1031, 'cloudcover': 9, 'heatindex': -6, 'dewpoint': -8, 'windchill': -6, 'windgust': 9, 'feelslike': -6, 'chanceofrain': 0, 'chanceofremdry': 0, 'chanceofwindy': 0, 'chanceofovercast': 0, 'chanceofsunshine': 0, 'chanceoffrost': 0, 'chanceofhightemp': 0, 'chanceoffog': 0, 'chanceofsnow': 0, 'chanceofthunder': 0, 'uv_index': 2}, {'time': '900', 'temperature': -5, 'wind_speed': 6, 'wind_degree': 10, 'wind_dir': 'N', 'weather_code': 113, 'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'], 'weather_descriptions': ['Sunny'], 'precip': 0, 'humidity': 79, 'visibility': 10, 'pressure': 1032, 'cloudcover': 11, 'heatindex': -5, 'dewpoint': -8, 'windchill': -8, 'windgust': 11, 'feelslike': -8, 'chanceofrain': 0, 'chanceofremdry': 0, 'chanceofwindy': 0, 'chanceofovercast': 0, 'chanceofsunshine': 0, 'chanceoffrost': 0, 'chanceofhightemp': 0, 'chanceoffog': 0, 'chanceofsnow': 0, 'chanceofthunder': 0, 'uv_index': 2}, {'time': '1200', 'temperature': 1, 'wind_speed': 6, 'wind_degree': 295, 'wind_dir': 'WNW', 'weather_code': 113, 'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'], 'weather_descriptions': ['Sunny'], 'precip': 0, 'humidity': 61, 'visibility' ...

# %% [markdown]
# Stored the response in json

# %%
test2 = json.loads(response.content)
test2
# Out:
# {'request': {'type': 'City',
#   'query': 'Salt Lake City, United States of America',
#   'language': 'en',
#   'unit': 'm'},
#  'location': {'name': 'Salt Lake City',
#   'country': 'United States of America',
#   'region': 'Utah',
#   'lat': '40.761',
#   'lon': '-111.890',
#   'timezone_id': 'America/Denver',
#   'localtime': '2025-03-28 20:33',
#   'localtime_epoch': 1743193980,
#   'utc_offset': '-6.0'},
#  'current': {'observation_time': '02:33 AM',
#   'temperature': 11,
#   'weather_code': 116,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'],
#   'weather_descriptions': ['Partly cloudy'],
#   'wind_speed': 4,
#   'wind_degree': 324,
#   'wind_dir': 'NW',
#   'pressure': 1009,
#   'precip': 0,
#   'humidity': 41,
#   'cloudcover': 75,
#   'feelslike': 11,
#   'uv_index': 0,
#   'visibility': 14,
#   'is_day': 'no'},
#  'historical': {'2015-01-21': {'date': '2015-01-21',
#    'date_epoch': 1421798400,
#    'astro': {'sunrise': '07:47 AM',
#     'sunset': '05:32 PM',
#     'moonrise': '08:18 AM',
#     'moonset': '07:25 PM',
#     'moon_phase': 'Waxing Crescent',
#     'moon_illumination': 3},
#    'mintemp': -6,
#    'maxtemp': 1,
#    'avgtemp': -3,
#    'totalsnow': 0,
#    'sunhour': 10,
#    'uv_index': 2,
#    'hourly': [{'time': '0',
#      'temperature': -3,
#      'wind_speed': 5,
#      'wind_degree': 354,
#      'wind_dir': 'N',
#      'weather_code': 113,
#      'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#      'weather_descriptions': ['Clear'],
#      'precip': 0,
#      'humidity': 77,
#      'visibility': 10,
#      'pressure': 1028,
#      'cloudcover': 10,
#      'heatindex': -3,
#      'dewpoint': -7,
#      'windchill': -5,
#      'windgust': 10,
#      'feelslike': -5,
#      'chanceofrain': 0,
#      'chanceofremdry': 0,
#      'chanceofwindy': 0,
#      'chanceofovercast': 0,
#      'chanceofsunshine': 0,
#      'chanceoffrost': 0,
#      'chanceofhightemp': 0,
#      'chanceoffog': 0,
#      'chanceofsnow': 0,
#      'chanceofthunder': 0,
#      'uv_index': 1},
#     {'time': '300',
#      'temperature': -4,
#      'wind_speed': 5,
#      'wind_degree': 9,
#      'wind_dir': 'N',
#      'weather_code': 113,
#      'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#      'weather_descriptions': ['Clear'],
#      'precip': 0,
#      'humidity': 78,
#      'visibility': 10,
#      'pressure': 1029,
#      'cloudcover': 6,
#      'heatindex': -4,
#      'dewpoint': -7,
#      'windchill': -6,
#      'windgust': 9,
#      'feelslike': -6,
#      'chanceofrain': 0,
#      'chanceofremdry': 0,
#      'chanceofwindy': 0,
#      'chanceofovercast': 0,
#      'chanceofsunshine': 0,
#      'chanceoffrost': 0,
#      'chanceofhightemp': 0,
#      'chanceoffog': 0,
#      'chanceofsnow': 0,
#      'chanceofthunder': 0,
#      'uv_index': 1},
#     {'time': '600',
#      'temperature': -6,
#      'wind_speed': 3,
#      'wind_degree': 285,
#      'wind_dir': 'WNW',
#      'weather_code': 113,
#      'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'],
#      'weather_descriptions': ['Sunny'],
#      'precip': 0,
#      'humidity': 80,
#      'visibility': 10,
#      'pressure': 1031,
#      'cloudcover': 9,
#      'heatindex': -6,
#      'dewpoint': -8,
#      'windchill': -6,
#      'windgust': 9,
#      'feelslike': -6,
#      'chanceofrain': 0,
#      'chanceofremdry': 0,
#      'chanceofwindy': 0,
#      'chanceofovercast': 0,
#      'chanceofsunshine': 0,
#      'chanceoffrost': 0,
#      'chanceofhightemp': 0,
#      'chanceoffog': 0,
#      'chanceofsnow': 0,
#      'chanceofthunder': 0,
#      'uv_index': 2},
#     {'time': '900',
#      'temperature': -5,
#      'wind_speed': 6,
#      'wind_degree': 10,
#      'wind_dir': 'N',
#      'weather_code': 113,
#      'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'],
#      'weather_descriptions': ['Sunny'],
#      'precip': 0,
#      'humidity': 79,
#      'visibility': 10,
#      'pressure': 1032,
#      'cloudcover': 11,
#      'heatindex': -5,
#      'dewpoint': -8,
#      'windchill': -8,
#      'windgust': 11,
#      'feelslike': -8,
#      'chanceofrain': 0,
#      'chanceofremdry': 0,
#      'chanceofwindy': 0,
#      'chanceofovercast': 0,
#      'chanceofsunshine': 0,
#      'chanceoffrost': 0,
#      'chanceofhightemp': 0,
#      'chanceoffog': 0,
#      'chanceofsnow': 0,
#      'chanceofthunder': 0,
#      'uv_index': 2},
#     {'time': '1200',
#      'temperature': 1,
#      'wind_speed': 6,
#      'wind_degree': 295,
#      'wind_dir': 'WNW',
#      'weather_code': 113,
#      'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'],
#      'weather_descriptions': ['Sunny'],
#      'precip': 0,
#      'humidity': 61,
#      'visibility': 10,
#      'pressure': 1031,
#      'cloudcover': 9,
#      'heatindex': 1,
#      'dewpoint': -6,
#      'windchill': -1,
#      'windgust': 21,
#      'feelslike': -1,
#      'chanceofrain': 0,
#      'chanceofremdry': 0,
#      'chanceofwindy': 0,
#      'chanceofovercast': 0,
#      'chanceofsunshine': 0,
#      'chanceoffrost': 0,
#      'chanceofhightemp': 0,
#      'chanceoffog': 0,
#      'chanceofsnow': 0,
#      'chanceofthunder': 0,
#      'uv_index': 2},
#     {'time': '1500',
#      'temperature': 1,
#      'wind_speed': 10,
#      'wind_degree': 324,
#      'wind_dir': 'NW',
#      'weather_code': 113,
#      'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'],
#      'weather_descriptions': ['Sunny'],
#      'precip': 0,
#      'humidity': 56,
#      'visibility': 10,
#      'pressure': 1031,
#      'cloudcover': 9,
#      'heatindex': 1,
#      'dewpoint': -7,
#      'windchill': -2,
#      'windgust': 23,
#      'feelslike': -2,
#      'chanceofrain': 0,
#      'chanceofremdry': 0,
#      'chanceofwindy': 0,
#      'chanceofovercast': 0,
#      'chanceofsunshine': 0,
#      'chanceoffrost': 0,
#      'chanceofhightemp': 0,
#      'chanceoffog': 0,
#      'chanceofsnow': 0,
#      'chanceofthunder': 0,
#      'uv_index': 2},
#     {'time': '1800',
#      'temperature': -4,
#      'wind_speed': 12,
#      'wind_degree': 322,
#      'wind_dir': 'NW',
#      'weather_code': 113,
#      'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#      'weather_descriptions': ['Clear'],
#      'precip': 0,
#      'humidity': 66,
#      'visibility': 10,
#      'pressure': 1032,
#      'cloudcover': 8,
#      'heatindex': -4,
#      'dewpoint': -9,
#      'windchill': -8,
#      'windgust': 21,
#      'feelslike': -8,
#      'chanceofrain': 0,
#      'chanceofremdry': 0,
#      'chanceofwindy': 0,
#      'chanceofovercast': 0,
#      'chanceofsunshine': 0,
#      'chanceoffrost': 0,
#      'chanceofhightemp': 0,
#      'chanceoffog': 0,
#      'chanceofsnow': 0,
#      'chanceofthunder': 0,
#      'uv_index': 1},
#     {'time': '2100',
#      'temperature': -5,
#      'wind_speed': 5,
#      'wind_degree': 13,
#      'wind_dir': 'NNE',
#      'weather_code': 113,
#      'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#      'weather_descriptions': ['Clear'],
#      'precip': 0,
#      'humidity': 71,
#      'visibility': 10,
#      'pressure': 1034,
#      'cloudcover': 6,
#      'heatindex': -5,
#      'dewpoint': -9,
#      'windchill': -7,
#      'windgust': 10,
#      'feelslike': -7,
#      'chanceofrain': 0,
#      'chanceofremdry': 0,
#      'chanceofwindy': 0,
#      'chanceofovercast': 0,
#      'chanceofsunshine': 0,
#      'chanceoffrost': 0,
#      'chanceofhightemp': 0,
#      'chanceoffog': 0,
#      'chanceofsnow': 0,
#      'chanceofthunder': 0,
#      'uv_index': 1}]}}}

# %% [markdown]
# Pulled the hourly data into a seperate variable. Tested whether storing each hours (8 per day) data was neccessary, decided to just keep the data from noon (time : 1200) for simplicity.

# %%
hourly_data = test2['historical']['2015-01-21']['hourly']
hourly_data
# Out:
# [{'time': '0',
#   'temperature': -3,
#   'wind_speed': 5,
#   'wind_degree': 354,
#   'wind_dir': 'N',
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#   'weather_descriptions': ['Clear'],
#   'precip': 0,
#   'humidity': 77,
#   'visibility': 10,
#   'pressure': 1028,
#   'cloudcover': 10,
#   'heatindex': -3,
#   'dewpoint': -7,
#   'windchill': -5,
#   'windgust': 10,
#   'feelslike': -5,
#   'chanceofrain': 0,
#   'chanceofremdry': 0,
#   'chanceofwindy': 0,
#   'chanceofovercast': 0,
#   'chanceofsunshine': 0,
#   'chanceoffrost': 0,
#   'chanceofhightemp': 0,
#   'chanceoffog': 0,
#   'chanceofsnow': 0,
#   'chanceofthunder': 0,
#   'uv_index': 1},
#  {'time': '300',
#   'temperature': -4,
#   'wind_speed': 5,
#   'wind_degree': 9,
#   'wind_dir': 'N',
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#   'weather_descriptions': ['Clear'],
#   'precip': 0,
#   'humidity': 78,
#   'visibility': 10,
#   'pressure': 1029,
#   'cloudcover': 6,
#   'heatindex': -4,
#   'dewpoint': -7,
#   'windchill': -6,
#   'windgust': 9,
#   'feelslike': -6,
#   'chanceofrain': 0,
#   'chanceofremdry': 0,
#   'chanceofwindy': 0,
#   'chanceofovercast': 0,
#   'chanceofsunshine': 0,
#   'chanceoffrost': 0,
#   'chanceofhightemp': 0,
#   'chanceoffog': 0,
#   'chanceofsnow': 0,
#   'chanceofthunder': 0,
#   'uv_index': 1},
#  {'time': '600',
#   'temperature': -6,
#   'wind_speed': 3,
#   'wind_degree': 285,
#   'wind_dir': 'WNW',
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'],
#   'weather_descriptions': ['Sunny'],
#   'precip': 0,
#   'humidity': 80,
#   'visibility': 10,
#   'pressure': 1031,
#   'cloudcover': 9,
#   'heatindex': -6,
#   'dewpoint': -8,
#   'windchill': -6,
#   'windgust': 9,
#   'feelslike': -6,
#   'chanceofrain': 0,
#   'chanceofremdry': 0,
#   'chanceofwindy': 0,
#   'chanceofovercast': 0,
#   'chanceofsunshine': 0,
#   'chanceoffrost': 0,
#   'chanceofhightemp': 0,
#   'chanceoffog': 0,
#   'chanceofsnow': 0,
#   'chanceofthunder': 0,
#   'uv_index': 2},
#  {'time': '900',
#   'temperature': -5,
#   'wind_speed': 6,
#   'wind_degree': 10,
#   'wind_dir': 'N',
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'],
#   'weather_descriptions': ['Sunny'],
#   'precip': 0,
#   'humidity': 79,
#   'visibility': 10,
#   'pressure': 1032,
#   'cloudcover': 11,
#   'heatindex': -5,
#   'dewpoint': -8,
#   'windchill': -8,
#   'windgust': 11,
#   'feelslike': -8,
#   'chanceofrain': 0,
#   'chanceofremdry': 0,
#   'chanceofwindy': 0,
#   'chanceofovercast': 0,
#   'chanceofsunshine': 0,
#   'chanceoffrost': 0,
#   'chanceofhightemp': 0,
#   'chanceoffog': 0,
#   'chanceofsnow': 0,
#   'chanceofthunder': 0,
#   'uv_index': 2},
#  {'time': '1200',
#   'temperature': 1,
#   'wind_speed': 6,
#   'wind_degree': 295,
#   'wind_dir': 'WNW',
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'],
#   'weather_descriptions': ['Sunny'],
#   'precip': 0,
#   'humidity': 61,
#   'visibility': 10,
#   'pressure': 1031,
#   'cloudcover': 9,
#   'heatindex': 1,
#   'dewpoint': -6,
#   'windchill': -1,
#   'windgust': 21,
#   'feelslike': -1,
#   'chanceofrain': 0,
#   'chanceofremdry': 0,
#   'chanceofwindy': 0,
#   'chanceofovercast': 0,
#   'chanceofsunshine': 0,
#   'chanceoffrost': 0,
#   'chanceofhightemp': 0,
#   'chanceoffog': 0,
#   'chanceofsnow': 0,
#   'chanceofthunder': 0,
#   'uv_index': 2},
#  {'time': '1500',
#   'temperature': 1,
#   'wind_speed': 10,
#   'wind_degree': 324,
#   'wind_dir': 'NW',
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'],
#   'weather_descriptions': ['Sunny'],
#   'precip': 0,
#   'humidity': 56,
#   'visibility': 10,
#   'pressure': 1031,
#   'cloudcover': 9,
#   'heatindex': 1,
#   'dewpoint': -7,
#   'windchill': -2,
#   'windgust': 23,
#   'feelslike': -2,
#   'chanceofrain': 0,
#   'chanceofremdry': 0,
#   'chanceofwindy': 0,
#   'chanceofovercast': 0,
#   'chanceofsunshine': 0,
#   'chanceoffrost': 0,
#   'chanceofhightemp': 0,
#   'chanceoffog': 0,
#   'chanceofsnow': 0,
#   'chanceofthunder': 0,
#   'uv_index': 2},
#  {'time': '1800',
#   'temperature': -4,
#   'wind_speed': 12,
#   'wind_degree': 322,
#   'wind_dir': 'NW',
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#   'weather_descriptions': ['Clear'],
#   'precip': 0,
#   'humidity': 66,
#   'visibility': 10,
#   'pressure': 1032,
#   'cloudcover': 8,
#   'heatindex': -4,
#   'dewpoint': -9,
#   'windchill': -8,
#   'windgust': 21,
#   'feelslike': -8,
#   'chanceofrain': 0,
#   'chanceofremdry': 0,
#   'chanceofwindy': 0,
#   'chanceofovercast': 0,
#   'chanceofsunshine': 0,
#   'chanceoffrost': 0,
#   'chanceofhightemp': 0,
#   'chanceoffog': 0,
#   'chanceofsnow': 0,
#   'chanceofthunder': 0,
#   'uv_index': 1},
#  {'time': '2100',
#   'temperature': -5,
#   'wind_speed': 5,
#   'wind_degree': 13,
#   'wind_dir': 'NNE',
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#   'weather_descriptions': ['Clear'],
#   'precip': 0,
#   'humidity': 71,
#   'visibility': 10,
#   'pressure': 1034,
#   'cloudcover': 6,
#   'heatindex': -5,
#   'dewpoint': -9,
#   'windchill': -7,
#   'windgust': 10,
#   'feelslike': -7,
#   'chanceofrain': 0,
#   'chanceofremdry': 0,
#   'chanceofwindy': 0,
#   'chanceofovercast': 0,
#   'chanceofsunshine': 0,
#   'chanceoffrost': 0,
#   'chanceofhightemp': 0,
#   'chanceoffog': 0,
#   'chanceofsnow': 0,
#   'chanceofthunder': 0,
#   'uv_index': 1}]

# %% [markdown]
# ## Part 2: Storing key values
# As there were two sections of the json file that we needed (hourly and daily data), made two temporary pandas data frames that we merged into the final finished data frame.
# Tested various other options before settling on this version.
#
# (Kept the following panels as they were before the final revision was made in the actual API call.)

# %%
dirty_hourly = pd.DataFrame(hourly_data)
hourly = dirty_hourly[['time','temperature','wind_speed','wind_degree','precip','humidity','visibility','pressure','cloudcover','heatindex','dewpoint','windchill','windgust','feelslike']]
test65 = pd.DataFrame(hourly.iloc[4]).T.reset_index()
test65
# Out:
#    index  time temperature wind_speed wind_degree precip humidity visibility  \
# 0      4  1200           1          6         295      0       61         10
#
#   pressure cloudcover heatindex dewpoint windchill windgust feelslike
# 0     1031          9         1       -6        -1       21        -1

# %%
daily_num = [test2['historical']['2015-01-21']['date'],test2['historical']['2015-01-21']['mintemp'], test2['historical']['2015-01-21']['maxtemp'], test2['historical']['2015-01-21']['avgtemp'], test2['historical']['2015-01-21']['sunhour'],test2['historical']['2015-01-21']['uv_index'],test2['historical']['2015-01-21']['totalsnow']]
daily = pd.DataFrame(daily_num, index=['date','mintemp','maxtemp','avgtemp','sunhour','uv_index','totalsnow']).T

# %%
daily
# Out:
#          date mintemp maxtemp avgtemp sunhour uv_index totalsnow
# 0  2015-01-21      -6       1      -3      10        2         0

# %% [markdown]
# ## Part 3: Reducing Variables
# At this point we have only kept the columns that we determined had a chance to be significant in determining possible snowfall. This included removing any non int/double column and all of the 'chanceof' columns as keeping any (especially chanceofsnow) would defeat the purpose of the analysis.
#
# Below was the dataframe with each of the eight hours (time) still kept.
# While it was possible to extend the 'daily' variables into each of the eight rows, or create a higher dimensional dataframe, we determined that the extra data gained was not worth the added complexity that would be required to analysis data stored in either method.
# Having each day stored on a single row, (as is the case with the final dataframe) makes exploratory analysis much quicker and easier to understand.

# %%
final_df = pd.concat([daily, hourly], axis=1)
final_df
# Out:
#          date mintemp maxtemp avgtemp sunhour uv_index totalsnow  time  \
# 0  2015-01-21      -6       1      -3      10        2         0     0
# 1         NaN     NaN     NaN     NaN     NaN      NaN       NaN   300
# 2         NaN     NaN     NaN     NaN     NaN      NaN       NaN   600
# 3         NaN     NaN     NaN     NaN     NaN      NaN       NaN   900
# 4         NaN     NaN     NaN     NaN     NaN      NaN       NaN  1200
# 5         NaN     NaN     NaN     NaN     NaN      NaN       NaN  1500
# 6         NaN     NaN     NaN     NaN     NaN      NaN       NaN  1800
# 7         NaN     NaN     NaN     NaN     NaN      NaN       NaN  2100
#
#    temperature  wind_speed  ...  precip  humidity  visibility  pressure  \
# 0           -3           5  ...       0        77          10      1028
# 1           -4           5  ...       0        78          10      1029
# 2           -6           3  ...       0        80          10      1031
# 3           -5           6  ...       0        79          10      1032
# 4            1           6  ...       0        61          10      1031
# 5            1          10  ...       0        56          10      1031
# 6           -4          12  ...       0        66          10      1032
# 7           -5           5  ...       0        71          10      1034
#
#    cloudcover  heatindex  dewpoint  windchill  windgust  feelslike
# 0          10         -3        -7         -5        10         -5
# 1           6         -4        -7         -6         9         -6
# 2           9         -6        -8         -6         9         -6
# 3          11         -5        -8         -8        11         -8
# 4           9          1        -6         -1        21         -1
# 5           9          1        -7         -2        23         -2
# 6           8         -4        -9         -8        21         -8
# 7           6         -5        -9         -7        10         -7
#
# [8 rows x 21 columns]

# %% [markdown]
# (testing adding a row to the bottom of the data frame to make sure it worked properly [before the large API request])

# %%
final_df.loc[len(final_df)] = (final_df.loc[0])
final_df
# Out:
#          date mintemp maxtemp avgtemp sunhour uv_index totalsnow  time  \
# 0  2015-01-21      -6       1      -3      10        2         0     0
# 1         NaN     NaN     NaN     NaN     NaN      NaN       NaN   300
# 2         NaN     NaN     NaN     NaN     NaN      NaN       NaN   600
# 3         NaN     NaN     NaN     NaN     NaN      NaN       NaN   900
# 4         NaN     NaN     NaN     NaN     NaN      NaN       NaN  1200
# 5         NaN     NaN     NaN     NaN     NaN      NaN       NaN  1500
# 6         NaN     NaN     NaN     NaN     NaN      NaN       NaN  1800
# 7         NaN     NaN     NaN     NaN     NaN      NaN       NaN  2100
# 8  2015-01-21      -6       1      -3      10        2         0     0
#
#    temperature  wind_speed  ...  precip  humidity  visibility  pressure  \
# 0           -3           5  ...       0        77          10      1028
# 1           -4           5  ...       0        78          10      1029
# 2           -6           3  ...       0        80          10      1031
# 3           -5           6  ...       0        79          10      1032
# 4            1           6  ...       0        61          10      1031
# 5            1          10  ...       0        56          10      1031
# 6           -4          12  ...       0        66          10      1032
# 7           -5           5  ...       0        71          10      1034
# 8           -3           5  ...       0        77          10      1028
#
#    cloudcover  heatindex  dewpoint  windchill  windgust  feelslike
# 0          10         -3        -7         -5        10         -5
# 1           6         -4        -7         -6         9         -6
# 2           9         -6        -8         -6         9         -6
# 3          11         -5        -8         -8        11         -8
# 4           9          1        -6         -1        21         -1
# 5           9          1        -7         -2        23         -2
# 6           8         -4        -9         -8        21         -8
# 7           6         -5        -9         -7        10         -7
# 8          10         -3        -7         -5        10         -5
#
# [9 rows x 21 columns]

# %% [markdown]
# ## Part 4: Compiling the actual Dataframe
# After testing and deciding on what we wanted in the finalized dataframe, we initialized an empty dataframe with the column names that we wanted to record.

# %%
weather_df = pd.DataFrame(columns=['date','mintemp','maxtemp','avgtemp','sunhour','uv_index','totalsnow','index','time','temperature','wind_speed','wind_degree','precip','humidity','visibility','pressure','cloudcover','heatindex','dewpoint','windchill','windgust','feelslike'])
weather_df
# Out:
# Empty DataFrame
# Columns: [date, mintemp, maxtemp, avgtemp, sunhour, uv_index, totalsnow, index, time, temperature, wind_speed, wind_degree, precip, humidity, visibility, pressure, cloudcover, heatindex, dewpoint, windchill, windgust, feelslike]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Then we setup a loop to send API requests for the ten years we wanted data on (2015-2024) as well as the months that snowfall would be present (1-4,9-12). This left us with 2420 API requests to store in the DataFrame.
#
# We then implemented the finalized testing code from above into each iteration of the loop and stored it in the previously empty weather_df (see comments in code for what each part does).

# %%
months = ['01','02','03','04','09','10','11','12']
days = {'01':31,'02':28,'03':31,'04':30,'09':30,'10':31,'11':30,'12':31}
zero = ''
counter = 0
for year in range(2015,2025):
    for month in months:
        for day in range(1,days[month]+1):
            if(day < 10):
                zero = '0'+ str(day)
            else:
                zero = str(day)
            #Sets the querystring equal to the day. (Ignores leapdays)
            querystring = {"query":"Salt Lake City", "historical_date":f'{year}-{month}-{zero}', "hourly":1}
            response = requests.get(url, params=querystring)

            weather_json = json.loads(response.content)
            #Sets and cleans the data for hourly
            hourly_data = weather_json['historical'][f'{year}-{month}-{zero}']['hourly']
            dirty_hourly = pd.DataFrame(hourly_data)
            hourly = dirty_hourly[['time','temperature','wind_speed','wind_degree','precip','humidity','visibility','pressure','cloudcover','heatindex','dewpoint','windchill','windgust','feelslike']]
            hour = pd.DataFrame(hourly.iloc[4]).T.reset_index()
            #Sets and cleans the data for daily
            daily_num = [weather_json['historical'][f'{year}-{month}-{zero}']['date'],weather_json['historical'][f'{year}-{month}-{zero}']['mintemp'], weather_json['historical'][f'{year}-{month}-{zero}']['maxtemp'], weather_json['historical'][f'{year}-{month}-{zero}']['avgtemp'], weather_json['historical'][f'{year}-{month}-{zero}']['sunhour'], weather_json['historical'][f'{year}-{month}-{zero}']['uv_index'], weather_json['historical'][f'{year}-{month}-{zero}']['totalsnow']]
            daily = pd.DataFrame(daily_num, index=['date','mintemp','maxtemp','avgtemp','sunhour','uv_index','totalsnow']).T
            #Joins the two
            joined = pd.concat([daily, hour], axis=1)
            #Adds to end of complete dataframe
            weather_df.loc[len(weather_df)] = (joined.loc[0])
            counter += 1
            print(f'API request #{counter}')
# Out:
# API request #1
# API request #2
# API request #3
# API request #4
# API request #5
# API request #6
# API request #7
# API request #8
# API request #9
# API request #10
# API request #11
# API request #12
# API request #13
# API request #14
# API request #15
# API request #16
# API request #17
# API request #18
# API request #19
# API request #20
# API request #21
# API request #22
# API request #23
# API request #24
# API request #25
# API request #26
# API request #27
# API request #28
# API request #29
# API request #30
# API request #31
# API request #32
# API request #33
# API request #34
# API request #35
# API request #36
# API request #37
# API request #38
# API request #39
# API request #40
# API request #41
# API request #42
# API request #43
# API request #44
# API request #45
# API request #46
# API request #47
# API request #48
# API request #49
# API request #50
# API request #51
# API request #52
# API request #53
# API request #54
# API request #55
# API request #56
# API request #57
# API request #58
# API request #59
# API request #60
# API request #61
# API request #62
# API request #63
# API request #64
# API request #65
# API request #66
# API request #67
# API request #68
# API request #69
# API request #70
# API request #71
# API request #72
# API request #73
# API request #74
# API request #75
# API request #76
# API request #77
# API request #78
# API request #79
# API request #80
# API request #81
# API request #82
# API request #83
# API request #84
# API request #85
# API request #86
# API request #87
# API request #88
# API request #89
# API request #90
# API request #91
# API request #92
# API request #93
# API request #94
# API request #95
# API request #96
# API request #97
# API request #98
# API request #99
# API request #100
# API request #101
# API request #102
# API request #103
# API request #104
# API request #105
# API request #106
# API request #107
# API request #108
# API request #109
# API request #110
# API request #111
# API request #112
# API request #113
# API request #114
# API request #115
# API request #116
# API request #117
# API request #118
# API request #119
# API request #120
# API request #121
# API request #122
# API request #123
# API request #124
# API request #125
# API request #126
# API request #127
# API request #128
# API request #129
# API request #130
# API request #131
# API request #132
# API request #133
# API request #134
# API request #135
# API request #136
# API request #137
# API request #138
# API request #139
# API request #140
# API request #141
# API request #142
# API request #143
# API request #144
# API request #145
# API request #146
# API request #147
# API request #148
# API request #149
# API request #150
# API request #151
# API request #152
# API request #153
# API request #154
# API request #155
# API request #156
# API request #157
# API request #158
# API request #159
# API request #160
# API request #161
# API request #162
# API request #163
# API request #164
# API request #165
# API request #166
# API request #167
# API request #168
# API request #169
# API request #170
# API request #171
# API request #172
# API request #173
# API request #174
# API request #175
# API request #176
# API request #177
# API request #178
# API request #179
# API request #180
# API request #181
# API request #182
# API request #183
# API request #184
# API request #185
# API request #186
# API request #187
# API request #188
# API request #189
# API request #190
# API request #191
# API request #192
# API request #193
# API request #194
# API request #195
# API request #196
# API request #197
# API request #198
# API request #199
# API request #200
# API request #201
# API request #202
# API request #203
# API request #204
# API request #205
# API request #206
# API request #207
# API request #208
# API request #209
# API request #210
# API request #211
# API request #212
# API request #213
# API request #214
# API request #215
# API request #216
# API request #217
# API request #218
# API request #219
# API request #220
# API request #221
# API request #222
# API request #223
# API request #224
# API request #225
# API request #226
# API request #227
# API request #228
# API request #229
# API request #230
# API request #231
# API request #232
# API request #233
# API request #234
# API request #235
# API request #236
# API request #237
# API request #238
# API request #239
# API request #240
# API request #241
# API request #242
# API request #243
# API request #244
# API request #245
# API request #246
# API request #247
# API request #248
# API request #249
# API request #250
# API request #251
# API request #252
# API request #253
# API request #254
# API request #255
# API request #256
# API request #257
# API request #258
# API request #259
# API request #260
# API request #261
# API request #262
# API request #263
# API request #264
# API request #265
# API request #266
# API request #267
# API request #268
# API request #269
# API request #270
# API request #271
# API request #272
# API request #273
# API request #274
# API request #275
# API request #276
# API request #277
# API request #278
# API request #279
# API request #280
# API request #281
# API request #282
# API request #283
# API request #284
# API request #285
# API request #286
# API request #287
# API request #288
# API request #289
# API request #290
# API request #291
# API request #292
# API request #293
# API request #294
# API request #295
# API request #296
# API request #297
# API request #298
# API request #299
# API request #300
# API request #301
# API request #302
# API request #303
# API request #304
# API request #305
# API request #306
# API request #307
# API request #308
# API request #309
# API request #310
# API request #311
# API request #312
# API request #313
# API request #314
# API request #315
# API request #316
# API request #317
# API request #318
# API request #319
# API request #320
# API request #321
# API request #322
# API request #323
# API request #324
# API request #325
# API request #326
# API request #327
# API request #328
# API request #329
# API request #330
# API request #331
# API request #332
# API request #333
# API request #334
# API request #335
# API request #336
# API request #337
# API request #338
# API request #339
# API request #340
# API request #341
# API request #342
# API request #343
# API request #344
# API request #345
# API request #346
# API request #347
# API request #348
# API request #349
# API request #350
# API request #351
# API request #352
# API request #353
# API request #354
# API request #355
# API request #356
# API request #357
# API request #358
# API request #359
# API request #360
# API request #361
# API request #362
# API request #363
# API request #364
# API request #365
# API request #366
# API request #367
# API request #368
# API request #369
# API request #370
# API request #371
# API request #372
# API request #373
# API request #374
# API request #375
# API request #376
# API request #377
# API request #378
# API request #379
# API request #380
# API request #381
# API request #382
# API request #383
# API request #384
# API request #385
# API request #386
# API request #387
# API request #388
# API request #389
# API request #390
# API request #391
# API request #392
# API request #393
# API request #394
# API request #395
# API request #396
# API request #397
# API request #398
# API request #399
# API request #400
# API request #401
# API request #402
# API request #403
# API request #404
# API request #405
# API request #406
# API request #407
# API request #408
# API request #409
# API request #410
# API request #411
# API request #412
# API request #413
# API request #414
# API request #415
# API request #416
# API request #417
# API request #418
# API request #419
# API request #420
# API request #421
# API request #422
# API request #423
# API request #424
# API request #425
# API request #426
# API request #427
# API request #428
# API request #429
# API request #430
# API request #431
# API request #432
# API request #433
# API request #434
# API request #435
# API request #436
# API request #437
# API request #438
# API request #439
# API request #440
# API request #441
# API request #442
# API request #443
# API request #444
# API request #445
# API request #446
# API request #447
# API request #448
# API request #449
# API request #450
# API request #451
# API request #452
# API request #453
# API request #454
# API request #455
# API request #456
# API request #457
# API request #458
# API request #459
# API request #460
# API request #461
# API request #462
# API request #463
# API request #464
# API request #465
# API request #466
# API request #467
# API request #468
# API request #469
# API request #470
# API request #471
# API request #472
# API request #473
# API request #474
# API request #475
# API request #476
# API request #477
# API request #478
# API request #479
# API request #480
# API request #481
# API request #482
# API request #483
# API request #484
# API request #485
# API request #486
# API request #487
# API request #488
# API request #489
# API request #490
# API request #491
# API request #492
# API request #493
# API request #494
# API request #495
# API request #496
# API request #497
# API request #498
# API request #499
# API request #500
# API request #501
# API request #502
# API request #503
# API request #504
# API request #505
# API request #506
# API request #507
# API request #508
# API request #509
# API request #510
# API request #511
# API request #512
# API request #513
# API request #514
# API request #515
# API request #516
# API request #517
# API request #518
# API request #519
# API request #520
# API request #521
# API request #522
# API request #523
# API request #524
# API request #525
# API request #526
# API request #527
# API request #528
# API request #529
# API request #530
# API request #531
# API request #532
# API request #533
# API request #534
# API request #535
# API request #536
# API request #537
# API request #538
# API request #539
# API request #540
# API request #541
# API request #542
# API request #543
# API request #544
# API request #545
# API request #546
# API request #547
# API request #548
# API request #549
# API request #550
# API request #551
# API request #552
# API request #553
# API request #554
# API request #555
# API request #556
# API request #557
# API request #558
# API request #559
# API request #560
# API request #561
# API request #562
# API request #563
# API request #564
# API request #565
# API request #566
# API request #567
# API request #568
# API request #569
# API request #570
# API request #571
# API request #572
# API request #573
# API request #574
# API request #575
# API request #576
# API request #577
# API request #578
# API request #579
# API request #580
# API request #581
# API request #582
# API request #583
# API request #584
# API request #585
# API request #586
# API request #587
# API request #588
# API request #589
# API request #590
# API request #591
# API request #592
# API request #593
# API request #594
# API request #595
# API request #596
# API request #597
# API request #598
# API request #599
# API request #600
# API request #601
# API request #602
# API request #603
# API request #604
# API request #605
# API request #606
# API request #607
# API request #608
# API request #609
# API request #610
# API request #611
# API request #612
# API request #613
# API request #614
# API request #615
# API request #616
# API request #617
# API request #618
# API request #619
# API request #620
# API request #621
# API request #622
# API request #623
# API request #624
# API request #625
# API request #626
# API request #627
# API request #628
# API request #629
# API request #630
# API request #631
# API request #632
# API request #633
# API request #634
# API request #635
# API request #636
# API request #637
# API request #638
# API request #639
# API request #640
# API request #641
# API request #642
# API request #643
# API request #644
# API request #645
# API request #646
# API request #647
# API request #648
# API request #649
# API request #650
# API request #651
# API request #652
# API request #653
# API request #654
# API request #655
# API request #656
# API request #657
# API request #658
# API request #659
# API request #660
# API request #661
# API request #662
# API request #663
# API request #664
# API request #665
# API request #666
# API request #667
# API request #668
# API request #669
# API request #670
# API request #671
# API request #672
# API request #673
# API request #674
# API request #675
# API request #676
# API request #677
# API request #678
# API request #679
# API request #680
# API request #681
# API request #682
# API request #683
# API request #684
# API request #685
# API request #686
# API request #687
# API request #688
# API request #689
# API request #690
# API request #691
# API request #692
# API request #693
# API request #694
# API request #695
# API request #696
# API request #697
# API request #698
# API request #699
# API request #700
# API request #701
# API request #702
# API request #703
# API request #704
# API request #705
# API request #706
# API request #707
# API request #708
# API request #709
# API request #710
# API request #711
# API request #712
# API request #713
# API request #714
# API request #715
# API request #716
# API request #717
# API request #718
# API request #719
# API request #720
# API request #721
# API request #722
# API request #723
# API request #724
# API request #725
# API request #726
# API request #727
# API request #728
# API request #729
# API request #730
# API request #731
# API request #732
# API request #733
# API request #734
# API request #735
# API request #736
# API request #737
# API request #738
# API request #739
# API request #740
# API request #741
# API request #742
# API request #743
# API request #744
# API request #745
# API request #746
# API request #747
# API request #748
# API request #749
# API request #750
# API request #751
# API request #752
# API request #753
# API request #754
# API request #755
# API request #756
# API request #757
# API request #758
# API request #759
# API request #760
# API request #761
# API request #762
# API request #763
# API request #764
# API request #765
# API request #766
# API request #767
# API request #768
# API request #769
# API request #770
# API request #771
# API request #772
# API request #773
# API request #774
# API request #775
# API request #776
# API request #777
# API request #778
# API request #779
# API request #780
# API request #781
# API request #782
# API request #783
# API request #784
# API request #785
# API request #786
# API request #787
# API request #788
# API request #789
# API request #790
# API request #791
# API request #792
# API request #793
# API request #794
# API request #795
# API request #796
# API request #797
# API request #798
# API request #799
# API request #800
# API request #801
# API request #802
# API request #803
# API request #804
# API request #805
# API request #806
# API request #807
# API request #808
# API request #809
# API request #810
# API request #811
# API request #812
# API request #813
# API request #814
# API request #815
# API request #816
# API request #817
# API request #818
# API request #819
# API request #820
# API request #821
# API request #822
# API request #823
# API request #824
# API request #825
# API request #826
# API request #827
# API request #828
# API request #829
# API request #830
# API request #831
# API request #832
# API request #833
# API request #834
# API request #835
# API request #836
# API request #837
# API request #838
# API request #839
# API request #840
# API request #841
# API request #842
# API request #843
# API request #844
# API request #845
# API request #846
# API request #847
# API request #848
# API request #849
# API request #850
# API request #851
# API request #852
# API request #853
# API request #854
# API request #855
# API request #856
# API request #857
# API request #858
# API request #859
# API request #860
# API request #861
# API request #862
# API request #863
# API request #864
# API request #865
# API request #866
# API request #867
# API request #868
# API request #869
# API request #870
# API request #871
# API request #872
# API request #873
# API request #874
# API request #875
# API request #876
# API request #877
# API request #878
# API request #879
# API request #880
# API request #881
# API request #882
# API request #883
# API request #884
# API request #885
# API request #886
# API request #887
# API request #888
# API request #889
# API request #890
# API request #891
# API request #892
# API request #893
# API request #894
# API request #895
# API request #896
# API request #897
# API request #898
# API request #899
# API request #900
# API request #901
# API request #902
# API request #903
# API request #904
# API request #905
# API request #906
# API request #907
# API request #908
# API request #909
# API request #910
# API request #911
# API request #912
# API request #913
# API request #914
# API request #915
# API request #916
# API request #917
# API request #918
# API request #919
# API request #920
# API request #921
# API request #922
# API request #923
# API request #924
# API request #925
# API request #926
# API request #927
# API request #928
# API request #929
# API request #930
# API request #931
# API request #932
# API request #933
# API request #934
# API request #935
# API request #936
# API request #937
# API request #938
# API request #939
# API request #940
# API request #941
# API request #942
# API request #943
# API request #944
# API request #945
# API request #946
# API request #947
# API request #948
# API request #949
# API request #950
# API request #951
# API request #952
# API request #953
# API request #954
# API request #955
# API request #956
# API request #957
# API request #958
# API request #959
# API request #960
# API request #961
# API request #962
# API request #963
# API request #964
# API request #965
# API request #966
# API request #967
# API request #968
# API request #969
# API request #970
# API request #971
# API request #972
# API request #973
# API request #974
# API request #975
# API request #976
# API request #977
# API request #978
# API request #979
# API request #980
# API request #981
# API request #982
# API request #983
# API request #984
# API request #985
# API request #986
# API request #987
# API request #988
# API request #989
# API request #990
# API request #991
# API request #992
# API request #993
# API request #994
# API request #995
# API request #996
# API request #997
# API request #998
# API request #999
# API request #1000
# API request #1001
# API request #1002
# API request #1003
# API request #1004
# API request #1005
# API request #1006
# API request #1007
# API request #1008
# API request #1009
# API request #1010
# API request #1011
# API request #1012
# API request #1013
# API request #1014
# API request #1015
# API request #1016
# API request #1017
# API request #1018
# API request #1019
# API request #1020
# API request #1021
# API request #1022
# API request #1023
# API request #1024
# API request #1025
# API request #1026
# API request #1027
# API request #1028
# API request #1029
# API request #1030
# API request #1031
# API request #1032
# API request #1033
# API request #1034
# API request #1035
# API request #1036
# API request #1037
# API request #1038
# API request #1039
# API request #1040
# API request #1041
# API request #1042
# API request #1043
# API request #1044
# API request #1045
# API request #1046
# API request #1047
# API request #1048
# API request #1049
# API request #1050
# API request #1051
# API request #1052
# API request #1053
# API request #1054
# API request #1055
# API request #1056
# API request #1057
# API request #1058
# API request #1059
# API request #1060
# API request #1061
# API request #1062
# API request #1063
# API request #1064
# API request #1065
# API request #1066
# API request #1067
# API request #1068
# API request #1069
# API request #1070
# API request #1071
# API request #1072
# API request #1073
# API request #1074
# API request #1075
# API request #1076
# API request #1077
# API request #1078
# API request #1079
# API request #1080
# API request #1081
# API request #1082
# API request #1083
# API request #1084
# API request #1085
# API request #1086
# API request #1087
# API request #1088
# API request #1089
# API request #1090
# API request #1091
# API request #1092
# API request #1093
# API request #1094
# API request #1095
# API request #1096
# API request #1097
# API request #1098
# API request #1099
# API request #1100
# API request #1101
# API request #1102
# API request #1103
# API request #1104
# API request #1105
# API request #1106
# API request #1107
# API request #1108
# API request #1109
# API request #1110
# API request #1111
# API request #1112
# API request #1113
# API request #1114
# API request #1115
# API request #1116
# API request #1117
# API request #1118
# API request #1119
# API request #1120
# API request #1121
# API request #1122
# API request #1123
# API request #1124
# API request #1125
# API request #1126
# API request #1127
# API request #1128
# API request #1129
# API request #1130
# API request #1131
# API request #1132
# API request #1133
# API request #1134
# API request #1135
# API request #1136
# API request #1137
# API request #1138
# API request #1139
# API request #1140
# API request #1141
# API request #1142
# API request #1143
# API request #1144
# API request #1145
# API request #1146
# API request #1147
# API request #1148
# API request #1149
# API request #1150
# API request #1151
# API request #1152
# API request #1153
# API request #1154
# API request #1155
# API request #1156
# API request #1157
# API request #1158
# API request #1159
# API request #1160
# API request #1161
# API request #1162
# API request #1163
# API request #1164
# API request #1165
# API request #1166
# API request #1167
# API request #1168
# API request #1169
# API request #1170
# API request #1171
# API request #1172
# API request #1173
# API request #1174
# API request #1175
# API request #1176
# API request #1177
# API request #1178
# API request #1179
# API request #1180
# API request #1181
# API request #1182
# API request #1183
# API request #1184
# API request #1185
# API request #1186
# API request #1187
# API request #1188
# API request #1189
# API request #1190
# API request #1191
# API request #1192
# API request #1193
# API request #1194
# API request #1195
# API request #1196
# API request #1197
# API request #1198
# API request #1199
# API request #1200
# API request #1201
# API request #1202
# API request #1203
# API request #1204
# API request #1205
# API request #1206
# API request #1207
# API request #1208
# API request #1209
# API request #1210
# API request #1211
# API request #1212
# API request #1213
# API request #1214
# API request #1215
# API request #1216
# API request #1217
# API request #1218
# API request #1219
# API request #1220
# API request #1221
# API request #1222
# API request #1223
# API request #1224
# API request #1225
# API request #1226
# API request #1227
# API request #1228
# API request #1229
# API request #1230
# API request #1231
# API request #1232
# API request #1233
# API request #1234
# API request #1235
# API request #1236
# API request #1237
# API request #1238
# API request #1239
# API request #1240
# API request #1241
# API request #1242
# API request #1243
# API request #1244
# API request #1245
# API request #1246
# API request #1247
# API request #1248
# API request #1249
# API request #1250
# API request #1251
# API request #1252
# API request #1253
# API request #1254
# API request #1255
# API request #1256
# API request #1257
# API request #1258
# API request #1259
# API request #1260
# API request #1261
# API request #1262
# API request #1263
# API request #1264
# API request #1265
# API request #1266
# API request #1267
# API request #1268
# API request #1269
# API request #1270
# API request #1271
# API request #1272
# API request #1273
# API request #1274
# API request #1275
# API request #1276
# API request #1277
# API request #1278
# API request #1279
# API request #1280
# API request #1281
# API request #1282
# API request #1283
# API request #1284
# API request #1285
# API request #1286
# API request #1287
# API request #1288
# API request #1289
# API request #1290
# API request #1291
# API request #1292
# API request #1293
# API request #1294
# API request #1295
# API request #1296
# API request #1297
# API request #1298
# API request #1299
# API request #1300
# API request #1301
# API request #1302
# API request #1303
# API request #1304
# API request #1305
# API request #1306
# API request #1307
# API request #1308
# API request #1309
# API request #1310
# API request #1311
# API request #1312
# API request #1313
# API request #1314
# API request #1315
# API request #1316
# API request #1317
# API request #1318
# API request #1319
# API request #1320
# API request #1321
# API request #1322
# API request #1323
# API request #1324
# API request #1325
# API request #1326
# API request #1327
# API request #1328
# API request #1329
# API request #1330
# API request #1331
# API request #1332
# API request #1333
# API request #1334
# API request #1335
# API request #1336
# API request #1337
# API request #1338
# API request #1339
# API request #1340
# API request #1341
# API request #1342
# API request #1343
# API request #1344
# API request #1345
# API request #1346
# API request #1347
# API request #1348
# API request #1349
# API request #1350
# API request #1351
# API request #1352
# API request #1353
# API request #1354
# API request #1355
# API request #1356
# API request #1357
# API request #1358
# API request #1359
# API request #1360
# API request #1361
# API request #1362
# API request #1363
# API request #1364
# API request #1365
# API request #1366
# API request #1367
# API request #1368
# API request #1369
# API request #1370
# API request #1371
# API request #1372
# API request #1373
# API request #1374
# API request #1375
# API request #1376
# API request #1377
# API request #1378
# API request #1379
# API request #1380
# API request #1381
# API request #1382
# API request #1383
# API request #1384
# API request #1385
# API request #1386
# API request #1387
# API request #1388
# API request #1389
# API request #1390
# API request #1391
# API request #1392
# API request #1393
# API request #1394
# API request #1395
# API request #1396
# API request #1397
# API request #1398
# API request #1399
# API request #1400
# API request #1401
# API request #1402
# API request #1403
# API request #1404
# API request #1405
# API request #1406
# API request #1407
# API request #1408
# API request #1409
# API request #1410
# API request #1411
# API request #1412
# API request #1413
# API request #1414
# API request #1415
# API request #1416
# API request #1417
# API request #1418
# API request #1419
# API request #1420
# API request #1421
# API request #1422
# API request #1423
# API request #1424
# API request #1425
# API request #1426
# API request #1427
# API request #1428
# API request #1429
# API request #1430
# API request #1431
# API request #1432
# API request #1433
# API request #1434
# API request #1435
# API request #1436
# API request #1437
# API request #1438
# API request #1439
# API request #1440
# API request #1441
# API request #1442
# API request #1443
# API request #1444
# API request #1445
# API request #1446
# API request #1447
# API request #1448
# API request #1449
# API request #1450
# API request #1451
# API request #1452
# API request #1453
# API request #1454
# API request #1455
# API request #1456
# API request #1457
# API request #1458
# API request #1459
# API request #1460
# API request #1461
# API request #1462
# API request #1463
# API request #1464
# API request #1465
# API request #1466
# API request #1467
# API request #1468
# API request #1469
# API request #1470
# API request #1471
# API request #1472
# API request #1473
# API request #1474
# API request #1475
# API request #1476
# API request #1477
# API request #1478
# API request #1479
# API request #1480
# API request #1481
# API request #1482
# API request #1483
# API request #1484
# API request #1485
# API request #1486
# API request #1487
# API request #1488
# API request #1489
# API request #1490
# API request #1491
# API request #1492
# API request #1493
# API request #1494
# API request #1495
# API request #1496
# API request #1497
# API request #1498
# API request #1499
# API request #1500
# API request #1501
# API request #1502
# API request #1503
# API request #1504
# API request #1505
# API request #1506
# API request #1507
# API request #1508
# API request #1509
# API request #1510
# API request #1511
# API request #1512
# API request #1513
# API request #1514
# API request #1515
# API request #1516
# API request #1517
# API request #1518
# API request #1519
# API request #1520
# API request #1521
# API request #1522
# API request #1523
# API request #1524
# API request #1525
# API request #1526
# API request #1527
# API request #1528
# API request #1529
# API request #1530
# API request #1531
# API request #1532
# API request #1533
# API request #1534
# API request #1535
# API request #1536
# API request #1537
# API request #1538
# API request #1539
# API request #1540
# API request #1541
# API request #1542
# API request #1543
# API request #1544
# API request #1545
# API request #1546
# API request #1547
# API request #1548
# API request #1549
# API request #1550
# API request #1551
# API request #1552
# API request #1553
# API request #1554
# API request #1555
# API request #1556
# API request #1557
# API request #1558
# API request #1559
# API request #1560
# API request #1561
# API request #1562
# API request #1563
# API request #1564
# API request #1565
# API request #1566
# API request #1567
# API request #1568
# API request #1569
# API request #1570
# API request #1571
# API request #1572
# API request #1573
# API request #1574
# API request #1575
# API request #1576
# API request #1577
# API request #1578
# API request #1579
# API request #1580
# API request #1581
# API request #1582
# API request #1583
# API request #1584
# API request #1585
# API request #1586
# API request #1587
# API request #1588
# API request #1589
# API request #1590
# API request #1591
# API request #1592
# API request #1593
# API request #1594
# API request #1595
# API request #1596
# API request #1597
# API request #1598
# API request #1599
# API request #1600
# API request #1601
# API request #1602
# API request #1603
# API request #1604
# API request #1605
# API request #1606
# API request #1607
# API request #1608
# API request #1609
# API request #1610
# API request #1611
# API request #1612
# API request #1613
# API request #1614
# API request #1615
# API request #1616
# API request #1617
# API request #1618
# API request #1619
# API request #1620
# API request #1621
# API request #1622
# API request #1623
# API request #1624
# API request #1625
# API request #1626
# API request #1627
# API request #1628
# API request #1629
# API request #1630
# API request #1631
# API request #1632
# API request #1633
# API request #1634
# API request #1635
# API request #1636
# API request #1637
# API request #1638
# API request #1639
# API request #1640
# API request #1641
# API request #1642
# API request #1643
# API request #1644
# API request #1645
# API request #1646
# API request #1647
# API request #1648
# API request #1649
# API request #1650
# API request #1651
# API request #1652
# API request #1653
# API request #1654
# API request #1655
# API request #1656
# API request #1657
# API request #1658
# API request #1659
# API request #1660
# API request #1661
# API request #1662
# API request #1663
# API request #1664
# API request #1665
# API request #1666
# API request #1667
# API request #1668
# API request #1669
# API request #1670
# API request #1671
# API request #1672
# API request #1673
# API request #1674
# API request #1675
# API request #1676
# API request #1677
# API request #1678
# API request #1679
# API request #1680
# API request #1681
# API request #1682
# API request #1683
# API request #1684
# API request #1685
# API request #1686
# API request #1687
# API request #1688
# API request #1689
# API request #1690
# API request #1691
# API request #1692
# API request #1693
# API request #1694
# API request #1695
# API request #1696
# API request #1697
# API request #1698
# API request #1699
# API request #1700
# API request #1701
# API request #1702
# API request #1703
# API request #1704
# API request #1705
# API request #1706
# API request #1707
# API request #1708
# API request #1709
# API request #1710
# API request #1711
# API request #1712
# API request #1713
# API request #1714
# API request #1715
# API request #1716
# API request #1717
# API request #1718
# API request #1719
# API request #1720
# API request #1721
# API request #1722
# API request #1723
# API request #1724
# API request #1725
# API request #1726
# API request #1727
# API request #1728
# API request #1729
# API request #1730
# API request #1731
# API request #1732
# API request #1733
# API request #1734
# API request #1735
# API request #1736
# API request #1737
# API request #1738
# API request #1739
# API request #1740
# API request #1741
# API request #1742
# API request #1743
# API request #1744
# API request #1745
# API request #1746
# API request #1747
# API request #1748
# API request #1749
# API request #1750
# API request #1751
# API request #1752
# API request #1753
# API request #1754
# API request #1755
# API request #1756
# API request #1757
# API request #1758
# API request #1759
# API request #1760
# API request #1761
# API request #1762
# API request #1763
# API request #1764
# API request #1765
# API request #1766
# API request #1767
# API request #1768
# API request #1769
# API request #1770
# API request #1771
# API request #1772
# API request #1773
# API request #1774
# API request #1775
# API request #1776
# API request #1777
# API request #1778
# API request #1779
# API request #1780
# API request #1781
# API request #1782
# API request #1783
# API request #1784
# API request #1785
# API request #1786
# API request #1787
# API request #1788
# API request #1789
# API request #1790
# API request #1791
# API request #1792
# API request #1793
# API request #1794
# API request #1795
# API request #1796
# API request #1797
# API request #1798
# API request #1799
# API request #1800
# API request #1801
# API request #1802
# API request #1803
# API request #1804
# API request #1805
# API request #1806
# API request #1807
# API request #1808
# API request #1809
# API request #1810
# API request #1811
# API request #1812
# API request #1813
# API request #1814
# API request #1815
# API request #1816
# API request #1817
# API request #1818
# API request #1819
# API request #1820
# API request #1821
# API request #1822
# API request #1823
# API request #1824
# API request #1825
# API request #1826
# API request #1827
# API request #1828
# API request #1829
# API request #1830
# API request #1831
# API request #1832
# API request #1833
# API request #1834
# API request #1835
# API request #1836
# API request #1837
# API request #1838
# API request #1839
# API request #1840
# API request #1841
# API request #1842
# API request #1843
# API request #1844
# API request #1845
# API request #1846
# API request #1847
# API request #1848
# API request #1849
# API request #1850
# API request #1851
# API request #1852
# API request #1853
# API request #1854
# API request #1855
# API request #1856
# API request #1857
# API request #1858
# API request #1859
# API request #1860
# API request #1861
# API request #1862
# API request #1863
# API request #1864
# API request #1865
# API request #1866
# API request #1867
# API request #1868
# API request #1869
# API request #1870
# API request #1871
# API request #1872
# API request #1873
# API request #1874
# API request #1875
# API request #1876
# API request #1877
# API request #1878
# API request #1879
# API request #1880
# API request #1881
# API request #1882
# API request #1883
# API request #1884
# API request #1885
# API request #1886
# API request #1887
# API request #1888
# API request #1889
# API request #1890
# API request #1891
# API request #1892
# API request #1893
# API request #1894
# API request #1895
# API request #1896
# API request #1897
# API request #1898
# API request #1899
# API request #1900
# API request #1901
# API request #1902
# API request #1903
# API request #1904
# API request #1905
# API request #1906
# API request #1907
# API request #1908
# API request #1909
# API request #1910
# API request #1911
# API request #1912
# API request #1913
# API request #1914
# API request #1915
# API request #1916
# API request #1917
# API request #1918
# API request #1919
# API request #1920
# API request #1921
# API request #1922
# API request #1923
# API request #1924
# API request #1925
# API request #1926
# API request #1927
# API request #1928
# API request #1929
# API request #1930
# API request #1931
# API request #1932
# API request #1933
# API request #1934
# API request #1935
# API request #1936
# API request #1937
# API request #1938
# API request #1939
# API request #1940
# API request #1941
# API request #1942
# API request #1943
# API request #1944
# API request #1945
# API request #1946
# API request #1947
# API request #1948
# API request #1949
# API request #1950
# API request #1951
# API request #1952
# API request #1953
# API request #1954
# API request #1955
# API request #1956
# API request #1957
# API request #1958
# API request #1959
# API request #1960
# API request #1961
# API request #1962
# API request #1963
# API request #1964
# API request #1965
# API request #1966
# API request #1967
# API request #1968
# API request #1969
# API request #1970
# API request #1971
# API request #1972
# API request #1973
# API request #1974
# API request #1975
# API request #1976
# API request #1977
# API request #1978
# API request #1979
# API request #1980
# API request #1981
# API request #1982
# API request #1983
# API request #1984
# API request #1985
# API request #1986
# API request #1987
# API request #1988
# API request #1989
# API request #1990
# API request #1991
# API request #1992
# API request #1993
# API request #1994
# API request #1995
# API request #1996
# API request #1997
# API request #1998
# API request #1999
# API request #2000
# API request #2001
# API request #2002
# API request #2003
# API request #2004
# API request #2005
# API request #2006
# API request #2007
# API request #2008
# API request #2009
# API request #2010
# API request #2011
# API request #2012
# API request #2013
# API request #2014
# API request #2015
# API request #2016
# API request #2017
# API request #2018
# API request #2019
# API request #2020
# API request #2021
# API request #2022
# API request #2023
# API request #2024
# API request #2025
# API request #2026
# API request #2027
# API request #2028
# API request #2029
# API request #2030
# API request #2031
# API request #2032
# API request #2033
# API request #2034
# API request #2035
# API request #2036
# API request #2037
# API request #2038
# API request #2039
# API request #2040
# API request #2041
# API request #2042
# API request #2043
# API request #2044
# API request #2045
# API request #2046
# API request #2047
# API request #2048
# API request #2049
# API request #2050
# API request #2051
# API request #2052
# API request #2053
# API request #2054
# API request #2055
# API request #2056
# API request #2057
# API request #2058
# API request #2059
# API request #2060
# API request #2061
# API request #2062
# API request #2063
# API request #2064
# API request #2065
# API request #2066
# API request #2067
# API request #2068
# API request #2069
# API request #2070
# API request #2071
# API request #2072
# API request #2073
# API request #2074
# API request #2075
# API request #2076
# API request #2077
# API request #2078
# API request #2079
# API request #2080
# API request #2081
# API request #2082
# API request #2083
# API request #2084
# API request #2085
# API request #2086
# API request #2087
# API request #2088
# API request #2089
# API request #2090
# API request #2091
# API request #2092
# API request #2093
# API request #2094
# API request #2095
# API request #2096
# API request #2097
# API request #2098
# API request #2099
# API request #2100
# API request #2101
# API request #2102
# API request #2103
# API request #2104
# API request #2105
# API request #2106
# API request #2107
# API request #2108
# API request #2109
# API request #2110
# API request #2111
# API request #2112
# API request #2113
# API request #2114
# API request #2115
# API request #2116
# API request #2117
# API request #2118
# API request #2119
# API request #2120
# API request #2121
# API request #2122
# API request #2123
# API request #2124
# API request #2125
# API request #2126
# API request #2127
# API request #2128
# API request #2129
# API request #2130
# API request #2131
# API request #2132
# API request #2133
# API request #2134
# API request #2135
# API request #2136
# API request #2137
# API request #2138
# API request #2139
# API request #2140
# API request #2141
# API request #2142
# API request #2143
# API request #2144
# API request #2145
# API request #2146
# API request #2147
# API request #2148
# API request #2149
# API request #2150
# API request #2151
# API request #2152
# API request #2153
# API request #2154
# API request #2155
# API request #2156
# API request #2157
# API request #2158
# API request #2159
# API request #2160
# API request #2161
# API request #2162
# API request #2163
# API request #2164
# API request #2165
# API request #2166
# API request #2167
# API request #2168
# API request #2169
# API request #2170
# API request #2171
# API request #2172
# API request #2173
# API request #2174
# API request #2175
# API request #2176
# API request #2177
# API request #2178
# API request #2179
# API request #2180
# API request #2181
# API request #2182
# API request #2183
# API request #2184
# API request #2185
# API request #2186
# API request #2187
# API request #2188
# API request #2189
# API request #2190
# API request #2191
# API request #2192
# API request #2193
# API request #2194
# API request #2195
# API request #2196
# API request #2197
# API request #2198
# API request #2199
# API request #2200
# API request #2201
# API request #2202
# API request #2203
# API request #2204
# API request #2205
# API request #2206
# API request #2207
# API request #2208
# API request #2209
# API request #2210
# API request #2211
# API request #2212
# API request #2213
# API request #2214
# API request #2215
# API request #2216
# API request #2217
# API request #2218
# API request #2219
# API request #2220
# API request #2221
# API request #2222
# API request #2223
# API request #2224
# API request #2225
# API request #2226
# API request #2227
# API request #2228
# API request #2229
# API request #2230
# API request #2231
# API request #2232
# API request #2233
# API request #2234
# API request #2235
# API request #2236
# API request #2237
# API request #2238
# API request #2239
# API request #2240
# API request #2241
# API request #2242
# API request #2243
# API request #2244
# API request #2245
# API request #2246
# API request #2247
# API request #2248
# API request #2249
# API request #2250
# API request #2251
# API request #2252
# API request #2253
# API request #2254
# API request #2255
# API request #2256
# API request #2257
# API request #2258
# API request #2259
# API request #2260
# API request #2261
# API request #2262
# API request #2263
# API request #2264
# API request #2265
# API request #2266
# API request #2267
# API request #2268
# API request #2269
# API request #2270
# API request #2271
# API request #2272
# API request #2273
# API request #2274
# API request #2275
# API request #2276
# API request #2277
# API request #2278
# API request #2279
# API request #2280
# API request #2281
# API request #2282
# API request #2283
# API request #2284
# API request #2285
# API request #2286
# API request #2287
# API request #2288
# API request #2289
# API request #2290
# API request #2291
# API request #2292
# API request #2293
# API request #2294
# API request #2295
# API request #2296
# API request #2297
# API request #2298
# API request #2299
# API request #2300
# API request #2301
# API request #2302
# API request #2303
# API request #2304
# API request #2305
# API request #2306
# API request #2307
# API request #2308
# API request #2309
# API request #2310
# API request #2311
# API request #2312
# API request #2313
# API request #2314
# API request #2315
# API request #2316
# API request #2317
# API request #2318
# API request #2319
# API request #2320
# API request #2321
# API request #2322
# API request #2323
# API request #2324
# API request #2325
# API request #2326
# API request #2327
# API request #2328
# API request #2329
# API request #2330
# API request #2331
# API request #2332
# API request #2333
# API request #2334
# API request #2335
# API request #2336
# API request #2337
# API request #2338
# API request #2339
# API request #2340
# API request #2341
# API request #2342
# API request #2343
# API request #2344
# API request #2345
# API request #2346
# API request #2347
# API request #2348
# API request #2349
# API request #2350
# API request #2351
# API request #2352
# API request #2353
# API request #2354
# API request #2355
# API request #2356
# API request #2357
# API request #2358
# API request #2359
# API request #2360
# API request #2361
# API request #2362
# API request #2363
# API request #2364
# API request #2365
# API request #2366
# API request #2367
# API request #2368
# API request #2369
# API request #2370
# API request #2371
# API request #2372
# API request #2373
# API request #2374
# API request #2375
# API request #2376
# API request #2377
# API request #2378
# API request #2379
# API request #2380
# API request #2381
# API request #2382
# API request #2383
# API request #2384
# API request #2385
# API request #2386
# API request #2387
# API request #2388
# API request #2389
# API request #2390
# API request #2391
# API request #2392
# API request #2393
# API request #2394
# API request #2395
# API request #2396
# API request #2397
# API request #2398
# API request #2399
# API request #2400
# API request #2401
# API request #2402
# API request #2403
# API request #2404
# API request #2405
# API request #2406
# API request #2407
# API request #2408
# API request #2409
# API request #2410
# API request #2411
# API request #2412
# API request #2413
# API request #2414
# API request #2415
# API request #2416
# API request #2417
# API request #2418
# API request #2419
# API request #2420

# %%
#Dropped the no longer needed columns 'index' and 'hour' which were left over from concat
#weather_df.drop('index')
#weather_df.drop('hour')
weather_df
# Out:
#             date mintemp maxtemp avgtemp sunhour uv_index totalsnow index  \
# 0     2015-01-01     -15      -7     -11      10        2         0     4
# 1     2015-01-02     -16      -4     -10      10        2         0     4
# 2     2015-01-03     -12      -2      -7      10        2         0     4
# 3     2015-01-04      -8       3      -3      10        2         0     4
# 4     2015-01-05      -4       5       1      10        2         0     4
# ...          ...     ...     ...     ...     ...      ...       ...   ...
# 2415  2024-12-27       0       4       2       1        1         0     4
# 2416  2024-12-28      -1       3       1       1        2       1.4     4
# 2417  2024-12-29       4       7       6       6        1         0     4
# 2418  2024-12-30      -5       4      -1       3        1       2.2     4
# 2419  2024-12-31      -6      -1      -4      10        2         0     4
#
#       time temperature  ... precip humidity visibility pressure cloudcover  \
# 0     1200          -7  ...      0       73         10     1029          3
# 1     1200          -6  ...      0       76         10     1029         10
# 2     1200          -2  ...      0       76         10     1027         46
# 3     1200           1  ...      0       72         10     1031         48
# 4     1200           4  ...      0       82         10     1030         32
# ...    ...         ...  ...    ...      ...        ...      ...        ...
# 2415  1200           2  ...    1.0       87          5     1008        100
# 2416  1200           4  ...    0.2       73         10     1018         73
# 2417  1200           9  ...    0.0       81         10     1009         97
# 2418  1200           1  ...    0.1       82          7     1030         85
# 2419  1200          -1  ...      0       60         10     1029          4
#
#      heatindex dewpoint windchill windgust feelslike
# 0           -7       -9       -11       13       -11
# 1           -6       -7        -6        6        -6
# 2           -2       -5        -3        9        -3
# 3            1       -4        -2       20        -2
# 4            4        1         0       29         0
# ...        ...      ...       ...      ...       ...
# 2415         2        0        -3       29        -3
# 2416         4        0         0       27         0
# 2417         9        2         6       49         6
# 2418         1       -4        -4       26        -4
# 2419        -1       -8        -2        4        -2
#
# [2420 rows x 22 columns]

# %% [markdown]
# ## Part 5: Saving as CSV file
# Lastly after completing the weather_df DataFrame we download the finished result as a csv file.

# %%
weather_df.to_csv('weather_df.csv', index = False)

# %% [markdown]
# # Cleaning the Data
# Before we can fully analyze the weather data and come to any conclusions, we must first clean the data.
#
# There are thousands of days in our dataset with no snowfall, as well as variables that really have no correlation with snow, so to help make our analysis simpler, we will get rid of all the unnecessary data.

# %% [markdown]
# ## Part 1: Importing the Necessary Packages
# The first thing we have to do is import all the packages we will need to clean the data.
#
# We will import Pandas to put all of our data into a DataFrame.
# <br>
# We will import Seaborn to create heatmaps for visualization.
# <br>
# We will import Matplotlib to display our heatmaps.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# ## Part 2: Importing the Data
# Now that we have our packages installed, we can load our data into a DataFrame, which we will use for our analysis.

# %%
weather = pd.read_csv('weather_df.csv')

print(weather.shape)
weather.head()
# Out:
# (2420, 22)
#          date  mintemp  maxtemp  avgtemp  sunhour  uv_index  totalsnow  index  \
# 0  2015-01-01      -15       -7      -11       10         2        0.0      4
# 1  2015-01-02      -16       -4      -10       10         2        0.0      4
# 2  2015-01-03      -12       -2       -7       10         2        0.0      4
# 3  2015-01-04       -8        3       -3       10         2        0.0      4
# 4  2015-01-05       -4        5        1       10         2        0.0      4
#
#    time  temperature  ...  precip  humidity  visibility  pressure  cloudcover  \
# 0  1200           -7  ...     0.0        73          10      1029           3
# 1  1200           -6  ...     0.0        76          10      1029          10
# 2  1200           -2  ...     0.0        76          10      1027          46
# 3  1200            1  ...     0.0        72          10      1031          48
# 4  1200            4  ...     0.0        82          10      1030          32
#
#    heatindex  dewpoint  windchill  windgust  feelslike
# 0         -7        -9        -11        13        -11
# 1         -6        -7         -6         6         -6
# 2         -2        -5         -3         9         -3
# 3          1        -4         -2        20         -2
# 4          4         1          0        29          0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Part 3: Initial Visualization
# Now that our data has been loaded in, we can start analyzing it and narrowing it down to what we need.
#
# First, we must get rid of the "date" column, as it is not in Float form.
# <br>
# Then, we can create a correlation heatmap to see what variables correlate the most with each other, and specifically with the "totalsnow" column.

# %%
weather_no_date = weather.drop('date', axis=1)

weather_correlation = weather_no_date.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(weather_correlation, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)

plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# ## Part 4: Filtering out Unnecessary Days
# Up until this point, we have been working with the entire dataset, including all of the days with no snow.
#
# To narrow down our dataset, we have chosen to only look at the days with snow, and the 2 days leading up to them.
# <br>
# This shortens our dataset from 2420 rows to just 511.

# %%
snow_indexes = weather_no_date.index[weather_no_date['totalsnow'] > 0]

keep_indexes = set()
for index in snow_indexes:
    keep_indexes.update([index, index - 1, index - 2])

keep_indexes = [i for i in keep_indexes if i in weather_no_date.index]

weather_filtered_rows = weather_no_date.loc[sorted(keep_indexes)]

print(weather_filtered_rows.shape)
weather_filtered_rows.head()
# Out:
# (479, 21)
#     mintemp  maxtemp  avgtemp  sunhour  uv_index  totalsnow  index  time  \
# 10       -1        6        3       10         1        0.0      4  1200
# 11        0        5        3       10         2        0.0      4  1200
# 12       -5        3       -1        8         1        1.4      4  1200
# 59       -3        6        2       11         2        0.0      4  1200
# 60       -1        6        3        7         2        0.0      4  1200
#
#     temperature  wind_speed  ...  precip  humidity  visibility  pressure  \
# 10            5           3  ...     0.0        88          10      1020
# 11            4           9  ...     0.7        85           5      1021
# 12            3          11  ...     0.0        83          10      1028
# 59            6           4  ...     0.3        55          10      1021
# 60            5           6  ...     0.4        65          10      1008
#
#     cloudcover  heatindex  dewpoint  windchill  windgust  feelslike
# 10          73          5         3          5        10          5
# 11          54          4         2          1        14          1
# 12          33          3         0         -1        24         -1
# 59          75          6        -3          5        11          5
# 60          52          5        -1          4        11          4
#
# [5 rows x 21 columns]

# %%
weather_filtered_rows_correlation = weather_filtered_rows.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(weather_filtered_rows_correlation, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)

plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# ## Part 5: Filtering out Unnecessary Columns
# Now that we have our correlation matrix based on just the days we are interested in, we can see which columns have little to no correlation with the "totalsnow" column.
# <br>
# We have chosen to eliminate all columns with a correlation of less than 0.2, which reduces the DataFrame from 20 columns to just 9.

# %%
snow_correlation = weather_filtered_rows.corr(numeric_only=True)['totalsnow']

strong_correlation_columns = snow_correlation[abs(snow_correlation) >= 0.2].index.tolist()

weather_filtered = weather_filtered_rows[strong_correlation_columns]

print(weather_filtered.shape)
weather_filtered.head()
# Out:
# (479, 12)
#     maxtemp  sunhour  uv_index  totalsnow  temperature  humidity  visibility  \
# 10        6       10         1        0.0            5        88          10
# 11        5       10         2        0.0            4        85           5
# 12        3        8         1        1.4            3        83          10
# 59        6       11         2        0.0            6        55          10
# 60        6        7         2        0.0            5        65          10
#
#     pressure  cloudcover  heatindex  windchill  feelslike
# 10      1020          73          5          5          5
# 11      1021          54          4          1          1
# 12      1028          33          3         -1         -1
# 59      1021          75          6          5          5
# 60      1008          52          5          4          4

# %%
weather_filtered_correlation = weather_filtered.corr()

plt.figure(figsize=(10, 6))
sns.heatmap(weather_filtered_correlation, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)

plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# # Exploratory Analysis
# We will now analyize the data to determine which factors strongly predict next-day snowfall.

# %% [markdown]
# ## Part 1: Univariate Analysis
# First, we will build histogram to visualize the distribution of each variable (like temperature, humidity, pressure, etc.) to understand their individual characteristics.

# %%
# Univariate Analysis: Histograms
plt.figure(figsize=(20, 15))
num_columns = len(hourly.columns[1:])
rows = (num_columns // 4) + 1
for i, column in enumerate(hourly.columns[1:], 1):
    plt.subplot(rows, 4, i)
    plt.hist(hourly[column], bins=20, edgecolor='black')
    plt.title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 2: Multivariate analysis
# Next, for multivariate analysis, we can build correlation heatmap (Seaborn) to identify the relationships between variables and scatter plots to show pairwise relationships between selected variables.

# %%
# Multivariate Analysis: Correlation Heatmap
plt.figure(figsize=(10, 8))
corr_matrix = hourly.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# Scatter Plots for Key Pairs
plt.figure(figsize=(15, 10))
key_pairs = [('temperature', 'humidity'), ('pressure', 'wind_speed'), ('wind_degree', 'wind_speed')]
for i, (x, y) in enumerate(key_pairs, 1):
    plt.subplot(2, 2, i)
    sns.scatterplot(data=hourly, x=x, y=y)
    plt.title(f'{x} vs {y}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 3: Statistical Testing
# For the next step of our analysis, we will conduct statistical testing and build predictive models to investigate the relationship between weather variables and snowfall.
# <br>
# First, we will perform a T-test to determine whether there are statistically significant differences in key weather variables (such as temperature, humidity, and pressure) between days with snowfall and days without snowfall.

# %%
from scipy import stats
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
# Check if 'totalsnow' column exists and identify snowfall days
if 'totalsnow' in daily.columns:
    snowfall_days = daily[daily['totalsnow'] > 0]
    no_snowfall_days = daily[daily['totalsnow'] == 0]

    # Perform T-Test
    for col in ['temperature', 'humidity', 'pressure']:
        t_stat, p_value = stats.ttest_ind(snowfall_days[col], no_snowfall_days[col], nan_policy='omit')
        print(f'T-Test for {col} between snowfall and non-snowfall days: t-statistic = {t_stat}, p-value = {p_value}')
else:
    print("Error: 'totalsnow' column not found in the dataset.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 8
#       6     # Perform T-Test
#       7     for col in ['temperature', 'humidity', 'pressure']:
# ----> 8         t_stat, p_value = stats.ttest_ind(snowfall_days[col], no_snowfall_days[col], nan_policy='omit')
#       9         print(f'T-Test for {col} between snowfall and non-snowfall days: t-statistic = {t_stat}, p-value = {p_value}')
#      10 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'temperature'

# %% [markdown]
# ## Part 4: Predictive Models
# Next, we will build regression models to predict next-day snowfall. A simple linear regression model will be used to explore the linear relationship between individual weather variables and snowfall. Additionally, we will construct a logistic regression model to predict the likelihood of snowfall based on multiple weather conditions.

# %%
# Simple Linear Regression Model (if 'totalsnow' is defined)
if 'totalsnow' in daily.columns:
    X = hourly[['temperature', 'humidity', 'pressure']]
    y = daily['totalsnow']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    model = LinearRegression()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Linear Regression Coefficients:", model.coef_)

# Logistic Regression for Snowfall Prediction using 'totalsnow'
if 'totalsnow' in daily.columns:
    X = hourly[['temperature', 'humidity', 'pressure']]
    y = (daily['totalsnow'] > 0).astype(int)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    log_model = LogisticRegression()
    log_model.fit(X_train, y_train)
    y_pred = log_model.predict(X_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 5
#       3 X = hourly[['temperature', 'humidity', 'pressure']]
#       4 y = daily['totalsnow']
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#       6 model = LinearRegression()
#       7 model.fit(X_train, y_train)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_split.py:2777, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2774 if n_arrays == 0:
#    2775     raise ValueError("At least one array required as input")
# -> 2777 arrays = indexable(*arrays)
#    2779 n_samples = _num_samples(arrays[0])
#    2780 n_train, n_test = _validate_shuffle_split(
#    2781     n_samples, test_size, train_size, default_test_size=0.25
#    2782 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:514, in indexable(*iterables)
#     484 """Make arrays indexable for cross-validation.
#     485
#     486 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     510 [[1, 2, 3], array([2, 3, 4]), None, <3x1 sparse matrix ...>]
#     511 """
#     513 result = [_make_indexable(X) for X in iterables]
# --> 514 check_consistent_length(*result)
#     515 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [8, 1]

# %% [markdown]
# # Project Schedule
# Apr 3rd -
# <br>
# Apr 15th -
# <br>
# Apr 17th -
